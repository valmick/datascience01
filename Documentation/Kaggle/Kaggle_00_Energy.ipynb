# %% [markdown]
# # ASHRAE Energy detection
# ---
# [link](https://www.kaggle.com/c/ashrae-energy-prediction) to the competition
#
#
# ## Imputation
# 1. Using SMOTE, ADSYN or GAN (https://arxiv.org/pdf/1904.09135.pdf) to generate missing data
#
# ## Feature Engineering
# ??
#
# ## Visualization
#
#
# ## Models
# 2. Catboost, xgboost, learn
#
# ## What about some NN model?
