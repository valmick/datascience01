# %% [markdown]
# # GAN based projects

# %% [markdown]
# ## References Ideas
# - [ ] Super resolution
# - [ ] https://skymind.ai/wiki/generative-adversarial-network-gan # Great resources on various topics on it
# - [ ] https://learning.oreilly.com/library/view/generative-adversarial-networks/9781789136678/fe014a9e-b46b-4b94-ade5-5d2c98be4f66.xhtml
# - [ ] Anomaly detection using GAN https://www.kaggle.com/c/severstal-steel-defect-detection
# - [ ] https://github.com/valmick/gans-awesome-applications

# %%
- [ ]
