# %% [markdown]
# # Setup for jupyter notebooks
#
# For videos and other aspects

# %%
from IPython.display import YouTubeVideo

def display_yotube_video(url, width=500,height=400):
    """
    Displays a Youtube video in a Jupyter notebook.
    
    Args:
        url (string): a link to a Youtube video.
        **kwargs: further arguments for IPython.display.YouTubeVideo
    
    Returns:
        YouTubeVideo: a video that is displayed in your notebook.
    """
    tube,link,end = url.split("=")
    #return YouTubeVideo(link, width,height)

#display_yotube_video("https://www.youtube.com/watch?v=SFqna5ilqig")

# %% [markdown]
# ```python
# display_yotube_video("https://www.youtube.com/watch?v=SFqna5ilqig")
# ```

# %% [markdown]
# # How to work with Jupyter Notebook
# of-course we have Jupyterlab as well now, but if we are going to use Google Code Collab as one of the key tools besides Anaconda's Jupyter notebook, it is good to go with the Notebook itself

# %% [markdown]
# ## Google Code Collab
# Allows me to work from multiple machine, but to get around the issue of having to depend on internet, I use the local connect to local runtime
# [https://research.google.com/colaboratory/local-runtimes.html]
# follow the step and then make a note of the port no
#
# ```
# [I 11:07:03.559 NotebookApp] The port 8888 is already in use, trying another port.
# [I 11:07:03.560 NotebookApp] The port 8889 is already in use, trying another port.
# [I 11:07:03.561 NotebookApp] The port 8890 is already in use, trying another port.
# [I 11:07:03.561 NotebookApp] The port 8891 is already in use, trying another port.
# jupyter_http_over_ws extension initialized. Listening on /http_over_websocket
# [I 11:07:03.615 NotebookApp] [jupyter_nbextensions_configurator] enabled 0.4.0
# [I 11:07:03.652 NotebookApp] JupyterLab beta preview extension loaded from C:\Users\vguha\AppData\Local\Continuum\anaconda3\lib\site-packages\jupyterlab
# [I 11:07:03.653 NotebookApp] JupyterLab application directory is C:\Users\vguha\AppData\Local\Continuum\anaconda3\share\jupyter\lab
# [I 11:07:03.904 NotebookApp] Serving notebooks from local directory: C:\
# [I 11:07:03.904 NotebookApp] 0 active kernels
# [I 11:07:03.904 NotebookApp] The Jupyter Notebook is running at:
# [I 11:07:03.904 NotebookApp] http://localhost:8892/?token=6bab113a67978b792d2ede8b927a46875224eaaa7d3aecfe
# ```
#
# > Note you will have to cut-paste the a line in your browser after running the
# ```
# jupyter notebook \
#   --NotebookApp.allow_origin='https://colab.research.google.com' \
#   --port=8888 \
#   --NotebookApp.port_retries=0
# ```
# > Once the one-time-authenticated connection is done, you can move on to connect locally enabling to work on the local machine with code collab.

# %% [markdown]
# ### What things I like about Google Code-collab
# 1. The Contents on the left
# 2. Markdown
# (Of-course these are available via nbextensions)
# 3. One can use revision history to check out the diffs

# %% [markdown]
# ## Jupyter Notebook
# - [Install nbextension](https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/install.html)
# - [nbextension configurator](https://github.com/Jupyter-contrib/jupyter_nbextensions_configurator)

# %% [markdown]
# ## Video references
# - [Youtube for reproducible reserach](https://www.youtube.com/watch?v=IG3PcZ6EhiU&list=PLGVZCDnMOq0ocea1dd0it7jX7HgvZCjSW)

# %% [markdown]
# ### The concept of Reproducible Research
# As I understand pioneered by David Knuth, great resources regarding it on emacs+org-mode, and of-course Jupyter notebooks.
#
# (One thing I miss is a To-Do and Agenda system of org-mode)

# %% [markdown]
# # To Dos
# - [ ] Diff tool
# - [ ] How to write magic commands
# - [ ] Read more about the jupyter architecture
# - [ ] Code generation from Jupyter
